# %% [markdown]
# <a href="https://colab.research.google.com/github/sushmitha27kadam/test/blob/main/Copy_of_TELECOM_CHURN_EDA_Submission.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # **Project Name**    -

# %% [markdown]
# ##### **Project Type**    - EDA/Regression/Classification/Unsupervised
# ##### **Contribution**    - Individual/Team

# %% [markdown]
# # **Project Summary -**

# %% [markdown]
# Write the summary here within 500-600 words.

# %% [markdown]
# # **GitHub Link -**

# %% [markdown]
# Provide your GitHub Link here.

# %% [markdown]
# # **Problem Statement**

# %% [markdown]
# **Write Problem Statement Here.**
# Orange S.A., formerly France Télécom S.A., is a French multinational telecommunications corporation. The Orange Telecom's Churn Dataset, consists of cleaned customer activity data (features), along with a churn label specifying whether a customer cancelled the subscription. Explore and analyze the data to discover key factors responsible for customer churn and come up with ways/recommendations to ensure customer retention.

# %% [markdown]
# #### **Define Your Business Objective?**

# %% [markdown]
# Answer Here.

# %% [markdown]
# # **General Guidelines** : -

# %% [markdown]
# 1.   Well-structured, formatted, and commented code is required.
# 2.   Exception Handling, Production Grade Code & Deployment Ready Code will be a plus. Those students will be awarded some additional credits.
#
#      The additional credits will have advantages over other students during Star Student selection.
#
#              [ Note: - Deployment Ready Code is defined as, the whole .ipynb notebook should be executable in one go
#                        without a single error logged. ]
#
# 3.   Each and every logic should have proper comments.
# 4. You may add as many number of charts you want. Make Sure for each and every chart the following format should be answered.
#
#
# ```
# # Chart visualization code
# ```
#
#
# *   Why did you pick the specific chart?
# *   What is/are the insight(s) found from the chart?
# * Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.
#
# 5. You have to create at least 20 logical & meaningful charts having important insights.
#
#
# [ Hints : - Do the Vizualization in  a structured way while following "UBM" Rule.
#
# U - Univariate Analysis,
#
# B - Bivariate Analysis (Numerical - Categorical, Numerical - Numerical, Categorical - Categorical)
#
# M - Multivariate Analysis
#  ]

# %% [markdown]
# # ***Let's Begin !***

# %% [markdown]
# ## ***1. Know Your Data***

# %% [markdown]
# ### Import Libraries

# %%
# Import Libraries

# libraries that are used for analysis and visualization
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
# %matplotlib inline

# %% [markdown]
# ### Dataset Loading

# %%
# Load Dataset
file_path = '/content/Telecom Churn.csv'
TC_df=pd.read_csv(file_path)

# %% [markdown]
# ### Dataset First View

# %%
# Dataset First Look
# Viewing the top 5 rows to take a glimpse of the data

TC_df.head()
# Out:
#   State  Account length  Area code International plan Voice mail plan  \
# 0    KS             128        415                 No             Yes
# 1    OH             107        415                 No             Yes
# 2    NJ             137        415                 No              No
# 3    OH              84        408                Yes              No
# 4    OK              75        415                Yes              No
#
#    Number vmail messages  Total day minutes  Total day calls  \
# 0                     25              265.1              110
# 1                     26              161.6              123
# 2                      0              243.4              114
# 3                      0              299.4               71
# 4                      0              166.7              113
#
#    Total day charge  Total eve minutes  Total eve calls  Total eve charge  \
# 0             45.07              197.4               99             16.78
# ...

# %%
# Viewing the last 5 rows
TC_df.tail()
# Out:
#      State  Account length  Area code International plan Voice mail plan  \
# 3328    AZ             192        415                 No             Yes
# 3329    WV              68        415                 No              No
# 3330    RI              28        510                 No              No
# 3331    CT             184        510                Yes              No
# 3332    TN              74        415                 No             Yes
#
#       Number vmail messages  Total day minutes  Total day calls  \
# 3328                     36              156.2               77
# 3329                      0              231.1               57
# 3330                      0              180.8              109
# 3331                      0              213.8              105
# 3332                     25              234.4              113
#
#       Total day charge  Total eve minutes  Total eve calls  Total eve charge  \
# ...

# %% [markdown]
# ### Dataset Rows & Columns count

# %%
# Dataset Rows & Columns count

TC_df.shape
# Out:
# (3333, 20)

# %%
print(f'number of rows : {TC_df.shape[0]}  \nnumber of columns : {TC_df.shape[1]}')
# Out:
# number of rows : 3333
# number of columns : 20

# %% [markdown]
# ### Dataset Information

# %%
# Dataset Info
TC_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3333 entries, 0 to 3332
# Data columns (total 20 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   State                   3333 non-null   object
#  1   Account length          3333 non-null   int64
#  2   Area code               3333 non-null   int64
#  3   International plan      3333 non-null   object
#  4   Voice mail plan         3333 non-null   object
#  5   Number vmail messages   3333 non-null   int64
#  6   Total day minutes       3333 non-null   float64
#  7   Total day calls         3333 non-null   int64
#  8   Total day charge        3333 non-null   float64
#  9   Total eve minutes       3333 non-null   float64
#  10  Total eve calls         3333 non-null   int64
#  11  Total eve charge        3333 non-null   float64
#  12  Total night minutes     3333 non-null   float64
#  13  Total night calls       3333 non-null   int64
# ...

# %% [markdown]
# #### Duplicate Values

# %%
# Dataset Duplicate Value Count
value = len(TC_df[TC_df.duplicated()])
print("The number of duplicate values in the data set is = ",value)
# Out:
# The number of duplicate values in the data set is =  0

# %% [markdown]
# We found that there were no duplicate entries in the above data.

# %% [markdown]
# #### Missing Values/Null Values

# %%
# Missing Values/Null Values Count
print(TC_df.isnull().sum())
# Out:
# State                     0
# Account length            0
# Area code                 0
# International plan        0
# Voice mail plan           0
# Number vmail messages     0
# Total day minutes         0
# Total day calls           0
# Total day charge          0
# Total eve minutes         0
# Total eve calls           0
# Total eve charge          0
# Total night minutes       0
# Total night calls         0
# Total night charge        0
# Total intl minutes        0
# Total intl calls          0
# Total intl charge         0
# Customer service calls    0
# Churn                     0
# dtype: int64

# %% [markdown]
# We found that there were no missing values present  in the above data.

# %%
# Missing Values Percentage
round(TC_df.isna().sum()/len(TC_df)*100, 2)
# Out:
# State                     0.0
# Account length            0.0
# Area code                 0.0
# International plan        0.0
# Voice mail plan           0.0
# Number vmail messages     0.0
# Total day minutes         0.0
# Total day calls           0.0
# Total day charge          0.0
# Total eve minutes         0.0
# Total eve calls           0.0
# Total eve charge          0.0
# Total night minutes       0.0
# Total night calls         0.0
# Total night charge        0.0
# Total intl minutes        0.0
# Total intl calls          0.0
# Total intl charge         0.0
# Customer service calls    0.0
# Churn                     0.0
# dtype: float64

# %%
# Visualizing the missing values
import missingno as msno
msno.bar(TC_df, color='PURPLE',sort='ascending', figsize=(10,3), fontsize=15)
# Out:
# <Axes: >

# %%
# Visualizing the missing values using Heatmap
plt.figure(figsize=(12,4))
sns.heatmap(TC_df.isnull(),  cmap='gray')
# Out:
# <Axes: >

# %% [markdown]
# ### What did you know about your dataset?

# %% [markdown]
# The data comes from a French multinational telecommunications corporation. The Orange Telecom's Churn Dataset, consists of cleaned customer activity data (features), along with a churn label specifying whether a customer cancelled the subscription.
#
#
# From the shape attribute, we can see the shape of the data i.e number of records and number of columns in the dataset like (3333,20) so that particular dataset will have 3333 rows and 13 columns.

# %% [markdown]
# ## ***2. Understanding Your Variables***

# %%
# Dataset Columns
TC_df.columns
# Out:
# Index(['State', 'Account length', 'Area code', 'International plan',
#        'Voice mail plan', 'Number vmail messages', 'Total day minutes',
#        'Total day calls', 'Total day charge', 'Total eve minutes',
#        'Total eve calls', 'Total eve charge', 'Total night minutes',
#        'Total night calls', 'Total night charge', 'Total intl minutes',
#        'Total intl calls', 'Total intl charge', 'Customer service calls',
#        'Churn'],
#       dtype='object')

# %%
# Dataset Describe
TC_df.describe(include = "all")
# Out:
#        State  Account length    Area code International plan Voice mail plan  \
# count   3333     3333.000000  3333.000000               3333            3333
# unique    51             NaN          NaN                  2               2
# top       WV             NaN          NaN                 No              No
# freq     106             NaN          NaN               3010            2411
# mean     NaN      101.064806   437.182418                NaN             NaN
# std      NaN       39.822106    42.371290                NaN             NaN
# min      NaN        1.000000   408.000000                NaN             NaN
# 25%      NaN       74.000000   408.000000                NaN             NaN
# 50%      NaN      101.000000   415.000000                NaN             NaN
# 75%      NaN      127.000000   510.000000                NaN             NaN
# max      NaN      243.000000   510.000000                NaN             NaN
#
# ...

# %%
TC_df.describe().T
# Out:
#                          count        mean        std     min     25%     50%  \
# Account length          3333.0  101.064806  39.822106    1.00   74.00  101.00
# Area code               3333.0  437.182418  42.371290  408.00  408.00  415.00
# Number vmail messages   3333.0    8.099010  13.688365    0.00    0.00    0.00
# Total day minutes       3333.0  179.775098  54.467389    0.00  143.70  179.40
# Total day calls         3333.0  100.435644  20.069084    0.00   87.00  101.00
# Total day charge        3333.0   30.562307   9.259435    0.00   24.43   30.50
# Total eve minutes       3333.0  200.980348  50.713844    0.00  166.60  201.40
# Total eve calls         3333.0  100.114311  19.922625    0.00   87.00  100.00
# Total eve charge        3333.0   17.083540   4.310668    0.00   14.16   17.12
# Total night minutes     3333.0  200.872037  50.573847   23.20  167.00  201.20
# Total night calls       3333.0  100.107711  19.568609   33.00   87.00  100.00
# ...

# %% [markdown]
# ### Variables Description

# %% [markdown]
# Answer Here

# %% [markdown]
# ### Check Unique Values for each variable.

# %%
# Check Unique Values for each variable.
for i in TC_df.columns.tolist():   #loop over each column in the DataFrame and print its name and convert the list to a Python list
  print("No. of unique values in",i,"is",TC_df[i].nunique())
# Out:
# No. of unique values in State is 51
# No. of unique values in Account length is 212
# No. of unique values in Area code is 3
# No. of unique values in International plan is 2
# No. of unique values in Voice mail plan is 2
# No. of unique values in Number vmail messages is 46
# No. of unique values in Total day minutes is 1667
# No. of unique values in Total day calls is 119
# No. of unique values in Total day charge is 1667
# No. of unique values in Total eve minutes is 1611
# No. of unique values in Total eve calls is 123
# No. of unique values in Total eve charge is 1440
# No. of unique values in Total night minutes is 1591
# No. of unique values in Total night calls is 120
# No. of unique values in Total night charge is 933
# No. of unique values in Total intl minutes is 162
# No. of unique values in Total intl calls is 21
# No. of unique values in Total intl charge is 162
# No. of unique values in Customer service calls is 10
# No. of unique values in Churn is 2

# %% [markdown]
# ## 3. ***Data Wrangling***

# %% [markdown]
# ### Data Wrangling Code

# %%
# Write your code to make your dataset analysis ready.

# %% [markdown]
# ### What all manipulations have you done and insights you found?

# %% [markdown]
# Answer Here.

# %% [markdown]
# ## ***4. Data Vizualization, Storytelling & Experimenting with charts : Understand the relationships between variables***

# %% [markdown]
# #### Chart - 1

# %%
pd.crosstab(TC_df["State"], TC_df["Churn"]).T
# Out:
# State  AK  AL  AR  AZ  CA  CO  CT  DC  DE  FL  ...  SD  TN  TX  UT  VA  VT  \
# Churn                                          ...
# False  49  72  44  60  25  57  62  49  52  55  ...  52  48  54  62  72  65
# True    3   8  11   4   9   9  12   5   9   8  ...   8   5  18  10   5   8
#
# State  WA  WI  WV  WY
# Churn
# False  52  71  96  68
# True   14   7  10   9
#
# [2 rows x 51 columns]

# %%
# Chart - 1 visualization code
# Create a cross-tabulation
cross_tab = pd.crosstab(TC_df["State"], TC_df["Churn"])

# %%
# create a bar plot from the crosstab
cross_tab.plot.bar(figsize=(25, 6), color=["green","red"])

# add labels and title
plt.xlabel("Churn Status")
plt.ylabel("Frequency")
plt.title("Frequency of Churn Status by State")

# show the plot
plt.show()

# %%
# group the data by State and Churn, and count the number of True and False values
result = TC_df.groupby(["State", "Churn"]).size().unstack(fill_value=0)

# add labels and title
result.index.name = "State"
result.columns.name = "Churn Status"
result.columns = ["False", "True"]
result.plot.bar(stacked=True)

# add labels and title
plt.xlabel("State")
plt.ylabel("Count")
plt.title("Count of True and False Values by State")

# show the plot
plt.show()

# %%
result = TC_df.groupby(["State", "Churn"]).size().unstack(fill_value=0)

# count the number of True values based on each state
true_count = result[True]

# sort the values in descending order and display the top 10 values in a table form
top_10 = true_count.sort_values(ascending=False)[:10]
top_10.index.name = "State"
top_10.name = "True Count"
top_10 = top_10.reset_index()
print(top_10.to_string(index=False))
# Out:
# State  True Count
#    NJ          18
#    TX          18
#    MD          17
#    MI          16
#    MN          15
#    NY          15
#    MT          14
#    NV          14
#    MS          14
#    SC          14

# %%
# group the data by State and Churn, and count the number of True values
result = TC_df.groupby(["State", "Churn"]).size().unstack(fill_value=0)

# count the number of True values based on each state
true_count = result[True]

# sort the values in descending order and display the top 10 values in a table form
top_10 = true_count.sort_values(ascending=False)[:10]
top_10.index.name = "State"
top_10.name = "True Count"
top_10 = top_10.reset_index()

# create a bar chart to visualize the True count based on each state
plt.figure(figsize=(10, 6))
plt.bar(top_10["State"], top_10["True Count"], color=["blue", "orange", "green", "red", "purple", "brown", "pink", "gray", "olive", "cyan"])

# add labels and title
plt.xlabel("State")
plt.ylabel("True Count")
plt.title("Top 10 True Counts by State")

# show the plot
plt.show()

# %%
result = TC_df.groupby(["State", "Churn"]).size().unstack(fill_value=0)

# count the number of True values based on each state
true_count = result[True]

# sort the values in descending order and display the top 10 values in a table form
top_10 = true_count.sort_values(ascending=False)
top_10.index.name = "State"
top_10.name = "True Count"
top_10 = top_10.reset_index()
print(top_10.to_string(index=False))
# Out:
# State  True Count
#    NJ          18
#    TX          18
#    MD          17
#    MI          16
#    MN          15
#    NY          15
#    MT          14
#    NV          14
#    MS          14
#    SC          14
#    WA          14
#    KS          13
#    ME          13
#    CT          12
#    OR          11
#    NC          11
#    MA          11
#    AR          11
#    UT          10
#    WV          10
#    OH          10
#    OK           9
#    NH           9
#    WY           9
#    CA           9
#    IN           9
#    CO           9
#    ID           9
#    DE           9
#    FL           8
#    AL           8
#    KY           8
#    VT           8
#    SD           8
#    PA           8
#    GA           8
#    WI           7
#    MO           7
#    RI           6
#    NM           6
#    ND           6
#    TN           5
#    DC           5
#    IL           5
#    VA           5
#    NE           5
#    LA           4
#    AZ           4
#    HI           3
# ...

# %%
# group the data by State and Churn, and count the number of True values
result = TC_df.groupby(["State", "Churn"]).size().unstack(fill_value=0)

# count the number of True values based on each state
true_count = result[True]

# sort the values in descending order and display the top 10 values in a table form
top_10 = true_count.sort_values(ascending=False)
top_10.index.name = "State"
top_10.name = "True Count"
top_10 = top_10.reset_index()

# create a bar chart to visualize the True count based on each state
plt.figure(figsize=(20, 6))
plt.bar(top_10["State"], top_10["True Count"], color=[palette [i]  for i in range(51)])

# add labels and title
plt.xlabel("State")
plt.ylabel("True Count")
plt.title("Top 10 True Counts by State")

# show the plot
plt.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-29-faebc567a5b7> in <cell line: 15>()
#      13 # create a bar chart to visualize the True count based on each state
#      14 plt.figure(figsize=(20, 6))
# ---> 15 plt.bar(top_10["State"], top_10["True Count"], color=[palette [i]  for i in range(51)])
#      16
#      17 # add labels and title
#
# <ipython-input-29-faebc567a5b7> in <listcomp>(.0)
#      13 # create a bar chart to visualize the True count based on each state
#      14 plt.figure(figsize=(20, 6))
# ---> 15 plt.bar(top_10["State"], top_10["True Count"], color=[palette [i]  for i in range(51)])
#      16
#      17 # add labels and title
#
# NameError: name 'palette' is not defined

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# Answer Here.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# Answer Here

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# Answer Here

# %% [markdown]
# #### Chart - 2

# %%
# Chart - 2 visualization code

# Extract the "Voice mail plan" and "Churn" columns
voice_mail_churn = TC_df.groupby(['Voice mail plan', 'Churn']).size().unstack()

# Plot the stacked bar chart
voice_mail_churn.plot(kind='bar', stacked=True)

# Add labels and a title
plt.xlabel('Voice mail plan')
plt.ylabel('Count')
plt.title('Stacked Bar Plot of Voice mail plan and Churn')

# Show the plot
plt.show()

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# Answer Here.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# Answer Here

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# Answer Here

# %% [markdown]
# #### Chart - 3

# %%
# Chart - 3 visualization code

# Extract the "Voice mail plan" and "Churn" columns
voice_mail_churn = TC_df.groupby(['International plan', 'Churn']).size().unstack()

# Plot the stacked bar chart
voice_mail_churn.plot(kind='bar', stacked=True)

# Add labels and a title
plt.xlabel('Voice mail plan')
plt.ylabel('Count')
plt.title('Stacked Bar Plot of International plan and Churn')

# Show the plot
plt.show()

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# Answer Here.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# Answer Here

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# Answer Here

# %% [markdown]
# #### Chart - 4

# %%
# Chart - 4 visualization code

plt.figure(figsize=(10, 6))
sns.boxplot(x='Churn', y='Total day minutes', data=TC_df)
plt.title('Box Plot of Total day minutes by Churn')
plt.xlabel('Churn')
plt.ylabel('Total day minutes')
plt.show()

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# Answer Here.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# Answer Here

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# Answer Here

# %% [markdown]
# #### Chart - 5

# %%
# Chart - 5 visualization code

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# Answer Here.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# Answer Here

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# Answer Here

# %% [markdown]
# #### Chart - 6

# %%
# Chart - 6 visualization code

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# Answer Here.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# Answer Here

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# Answer Here

# %% [markdown]
# #### Chart - 7

# %%
# Chart - 7 visualization code

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# Answer Here.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# Answer Here

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# Answer Here

# %% [markdown]
# #### Chart - 8

# %%
# Chart - 8 visualization code

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# Answer Here.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# Answer Here

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# Answer Here

# %% [markdown]
# #### Chart - 9

# %%
# Chart - 9 visualization code

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# Answer Here.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# Answer Here

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# Answer Here

# %% [markdown]
# #### Chart - 10

# %%
# Chart - 10 visualization code

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# Answer Here.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# Answer Here

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# Answer Here

# %% [markdown]
# #### Chart - 11

# %%
# Chart - 11 visualization code

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# Answer Here.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# Answer Here

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# Answer Here

# %% [markdown]
# #### Chart - 12

# %%
# Chart - 12 visualization code

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# Answer Here.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# Answer Here

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# Answer Here

# %% [markdown]
# #### Chart - 13

# %%
# Chart - 13 visualization code
# Create a DataFrame with the state and churn variables
cross_tab = pd.crosstab(TC_df["State"], TC_df["Churn"])

# Set up the figure and plot the heat map
fig, ax = plt.subplots(figsize=(10, 6))
sns.heatmap(data=cross_tab, cmap='jet', linewidths=0.5, ax=ax)

# Customize the plot
ax.set_title('Telecom Churn Heat Map')
ax.set_xlabel('Churn')
ax.set_ylabel('State')

# Show the plot
plt.show()

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# Answer Here.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# Answer Here

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# Answer Here

# %% [markdown]
# #### Chart - 14 - Correlation Heatmap

# %%
# Correlation Heatmap visualization code

# Create the correlation matrix
corr_matrix = TC_df.corr()

# Plot the heatmap
plt.figure(figsize=(18, 8))
sns.heatmap(corr_matrix, annot=True, cmap='jet')
plt.title('Telecom Churn Correlation Heatmap')
plt.show()
# Out:
# <ipython-input-48-9067d3e1029f>:4: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   corr_matrix = TC_df.corr()

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# The correlation coefficient is a numerical measure of the strength and direction of a linear relationship between two variables. In other words, it measures the extent to which changes in one variable are associated with changes in the other variable. The correlation coefficient ranges from -1 to 1, with -1 indicating a perfect negative correlation, 1 indicating a perfect positive correlation, and 0 indicating no correlation.
#
# The correlation coefficient is an important tool in data analysis and machine learning, as it can help to identify relationships between variables and can be used in feature selection techniques to remove highly correlated features, which can reduce overfitting and improve the performance of the model.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# Answer Here

# %% [markdown]
# #### Chart - 15 - Pair Plot

# %%
# Pair Plot visualization
# Select the columns for the pair plot
columns = ['Voice mail plan', 'Churn', 'Number vmail messages', 'Total day minutes', 'Total day charge','Customer service calls','State']

# Create the pair plot
sns.pairplot(TC_df[columns], hue='Churn', palette='husl')

# Display the plot
plt.show()

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# Answer Here.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# Answer Here

# %% [markdown]
# ## **5. Solution to Business Objective**

# %% [markdown]
# #### What do you suggest the client to achieve Business Objective ?
# Explain Briefly.

# %% [markdown]
# Answer Here.

# %% [markdown]
# # **Conclusion**

# %% [markdown]
# Write the conclusion here.

# %% [markdown]
# ### ***Hurrah! You have successfully completed your EDA Capstone Project !!!***
